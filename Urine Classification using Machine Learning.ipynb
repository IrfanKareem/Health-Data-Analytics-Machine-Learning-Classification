# %% [markdown]
# #  Irfan Kareem
# RF Planning and Optimization Engineer<br>
# BSc Electronic Engineering, MS Computer Science<br>
# irfan.kareem273@gmail.com
# https://www.linkedin.com/in/irfan-kareem-a89ba021/
#
# 17-March-2020

# %% [markdown]
# # Import Required Libraries

# %%
import pandas as pd 
import os
from glob import glob
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Set Working Path

# %%
working_directory = 'D:/DataSet'
os.chdir(working_directory)

# %% [markdown]
# # Concat Give Data Set

# %%
# Check the File List in the given path
files = sorted(glob('*.csv'))
files
# Out:
# ['data_class1.csv', 'data_class2.csv']

# %%
# concat Data Sets
df=pd.concat((pd.read_csv(file,encoding='latin-1',header=None) for file in files))
# Remove Duplicate Rows
df=df.drop_duplicates()
# Assign row 0 as header
df.columns = df.iloc[0]
# remove row 0 from Data Frame
df=df.drop(df.index[[0]],axis=0)
# Export Data Set
#df.to_csv('output2.csv',index=False)

# %% [markdown]
# # Shpape of the Data Set

# %%
df.shape
# Out:
# (7368, 46)

# %% [markdown]
# # Check Variable List

# %%
df.keys()
# Out:
# Index(['cur_col_113', 'cur_col_114', 'cur_col_115', 'cur_col_116',
#        'cur_col_125', 'cur_col_126', 'cur_col_127', 'cur_col_128',
#        'cur_col_137', 'cur_col_138', 'cur_col_139', 'cur_col_140',
#        'cur_col_149', 'cur_col_150', 'cur_col_151', 'cur_col_152',
#        'cur_col_161', 'cur_col_162', 'cur_col_163', 'cur_col_164',
#        'cur_col_173', 'cur_col_174', 'cur_col_175', 'cur_col_176',
#        'cur_col_185', 'cur_col_186', 'cur_col_187', 'cur_col_188',
#        'cur_col_197', 'cur_col_198', 'cur_col_199', 'cur_col_200',
#        'cur_col_209', 'cur_col_210', 'cur_col_211', 'cur_col_212',
#        'cur_col_221', 'cur_col_222', 'cur_col_223', 'cur_col_224', 'timestamp',
#        'device_id', 'patientid', 'bedid', 'hubid', 'class'],
#       dtype='object', name=0)

# %% [markdown]
# # Data Set Preview

# %%
df.head(3)
# Out:
# 0 cur_col_113 cur_col_114 cur_col_115 cur_col_116 cur_col_125 cur_col_126  \
# 1        50.8        51.3        51.1        51.2        50.8        51.1
# 2        50.9        51.1        51.1        51.1        51.4        51.1
# 3        50.9        51.1        51.1        51.3        51.1        51.2
#
# 0 cur_col_127 cur_col_128 cur_col_137 cur_col_138  ... cur_col_221  \
# 1        51.1        51.1        51.1        51.1  ...        51.1
# 2        51.1        51.3        51.1        51.1  ...        50.9
# 3        51.1        51.2        51.2        51.2  ...        50.9
#
# 0 cur_col_222 cur_col_223 cur_col_224            timestamp          device_id  \
# 1        50.8        49.7        50.8  2019-07-23 04:33:17  00:07:32:54:5f:94
# 2        50.8        49.3        51.0  2019-07-23 04:32:33  00:07:32:54:5f:94
# 3        50.6        50.1        50.9  2019-07-23 04:35:05  00:07:32:54:5f:94
#
# 0 patientid  bedid  hubid  class
# 1  TGHC-006  2-001  3-001  urine
# ...

# %%
df.tail(3)
# Out:
# 0   cur_col_113 cur_col_114 cur_col_115 cur_col_116 cur_col_125 cur_col_126  \
# 597        53.1        55.8        55.8        55.5        52.5        54.1
# 598        53.1        55.8        55.8        55.6        52.5        54.1
# 599        53.1        55.9        55.8        55.6        52.8        54.1
#
# 0   cur_col_127 cur_col_128 cur_col_137 cur_col_138  ... cur_col_221  \
# 597        57.0        54.4        54.1        52.5  ...        50.5
# 598        57.0        54.4        54.1        52.5  ...        49.8
# 599        57.1        54.7        54.1        52.5  ...        50.2
#
# 0   cur_col_222 cur_col_223 cur_col_224            timestamp  \
# 597        51.7        52.4        51.7  2019-07-23 20:57:31
# 598        51.7        52.3        51.8  2019-07-23 20:57:36
# 599        51.7        52.3        51.7  2019-07-23 20:57:40
#
# 0            device_id patientid  bedid  hubid     class
# 597  00:07:32:54:5f:94  TGHC-013  2-001  3-001  no_urine
# ...

# %%
df.sample(3)
# Out:
# 0    cur_col_113 cur_col_114 cur_col_115 cur_col_116 cur_col_125 cur_col_126  \
# 637         55.3        60.2        59.8        59.6        53.2        57.4
# 2203        59.8        60.0        58.8        56.4        60.6        60.4
# 2256        59.9        60.1        58.8        56.4        60.6        60.5
#
# 0    cur_col_127 cur_col_128 cur_col_137 cur_col_138  ... cur_col_221  \
# 637         60.9        58.2        55.9        54.5  ...        49.5
# 2203        57.3        57.1        56.5        58.8  ...        55.4
# 2256        57.4        57.1        56.7        58.8  ...        55.2
#
# 0    cur_col_222 cur_col_223 cur_col_224            timestamp  \
# 637         51.6        52.3        51.1  2019-07-23 21:51:36
# 2203        52.7        48.6        49.3  2019-07-19 03:50:22
# 2256        52.6        48.4        49.5  2019-07-19 03:53:10
#
# 0             device_id patientid  bedid  hubid  class
# 637   00:07:32:54:5f:94  TGHC-013  2-001  3-001  urine
# ...

# %% [markdown]
# # Check Missing Values

# %%
df.isnull().sum()
# Out:
# 0
# cur_col_113    0
# cur_col_114    0
# cur_col_115    0
# cur_col_116    0
# cur_col_125    0
# cur_col_126    0
# cur_col_127    0
# cur_col_128    0
# cur_col_137    0
# cur_col_138    0
# cur_col_139    0
# cur_col_140    0
# cur_col_149    0
# cur_col_150    0
# cur_col_151    0
# cur_col_152    0
# cur_col_161    0
# cur_col_162    0
# cur_col_163    0
# cur_col_164    0
# cur_col_173    0
# cur_col_174    0
# cur_col_175    0
# cur_col_176    0
# cur_col_185    0
# cur_col_186    0
# cur_col_187    0
# cur_col_188    0
# cur_col_197    0
# cur_col_198    0
# cur_col_199    0
# cur_col_200    0
# cur_col_209    0
# cur_col_210    0
# cur_col_211    0
# cur_col_212    0
# cur_col_221    0
# cur_col_222    0
# cur_col_223    0
# cur_col_224    0
# timestamp      0
# device_id      0
# patientid      0
# bedid          0
# hubid          0
# class          0
# dtype: int64

# %% [markdown]
# # Check Data Types of the Data Frame

# %%
df.dtypes
# Out:
# 0
# cur_col_113    object
# cur_col_114    object
# cur_col_115    object
# cur_col_116    object
# cur_col_125    object
# cur_col_126    object
# cur_col_127    object
# cur_col_128    object
# cur_col_137    object
# cur_col_138    object
# cur_col_139    object
# cur_col_140    object
# cur_col_149    object
# cur_col_150    object
# cur_col_151    object
# cur_col_152    object
# cur_col_161    object
# cur_col_162    object
# cur_col_163    object
# cur_col_164    object
# cur_col_173    object
# cur_col_174    object
# cur_col_175    object
# cur_col_176    object
# cur_col_185    object
# cur_col_186    object
# cur_col_187    object
# cur_col_188    object
# cur_col_197    object
# cur_col_198    object
# cur_col_199    object
# cur_col_200    object
# cur_col_209    object
# cur_col_210    object
# cur_col_211    object
# cur_col_212    object
# cur_col_221    object
# cur_col_222    object
# cur_col_223    object
# cur_col_224    object
# timestamp      object
# ...

# %% [markdown]
# # Assigain Appropriate Data Types

# %%
cols = df.columns.drop(['timestamp','device_id','patientid','bedid','hubid','class'])
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')
# timestamp variable assign data type
df['timestamp'] = pd.to_datetime(df['timestamp'], infer_datetime_format=True)

# %%
df.dtypes
# Out:
# 0
# cur_col_113           float64
# cur_col_114           float64
# cur_col_115           float64
# cur_col_116           float64
# cur_col_125           float64
# cur_col_126           float64
# cur_col_127           float64
# cur_col_128           float64
# cur_col_137           float64
# cur_col_138           float64
# cur_col_139           float64
# cur_col_140           float64
# cur_col_149           float64
# cur_col_150           float64
# cur_col_151           float64
# cur_col_152           float64
# cur_col_161           float64
# cur_col_162           float64
# cur_col_163           float64
# cur_col_164           float64
# cur_col_173           float64
# cur_col_174           float64
# cur_col_175           float64
# cur_col_176           float64
# cur_col_185           float64
# cur_col_186           float64
# cur_col_187           float64
# cur_col_188           float64
# cur_col_197           float64
# cur_col_198           float64
# cur_col_199           float64
# ...

# %% [markdown]
# # Summary of the Data Set

# %%
# Summary of the Data Set only vaiable data type is float64
u=df.describe(include=['float64'])
# Transpose Data Set
u=u.T.reset_index()
# Re-name Column name
u=u.rename(columns={0:"Variable"})
u
# Export Data Set
#u.to_csv('output3.csv',index=False)
# Out:
#        Variable   count       mean       std   min     25%   50%   75%   max
# 0   cur_col_113  7368.0  58.947109  3.360538  50.8  57.175  60.0  61.2  64.0
# 1   cur_col_114  7368.0  59.276099  3.145616  50.9  59.000  60.0  61.3  64.3
# 2   cur_col_115  7368.0  58.291979  2.914673  51.0  58.000  58.9  59.6  64.5
# 3   cur_col_116  7368.0  57.732071  2.712088  49.3  56.400  59.0  59.3  62.6
# 4   cur_col_125  7368.0  58.922109  3.743888  50.7  57.000  60.5  61.8  62.5
# 5   cur_col_126  7368.0  59.254492  3.343623  50.9  59.000  60.0  61.3  62.6
# 6   cur_col_127  7368.0  58.836726  3.313177  50.8  57.300  58.8  62.4  63.7
# 7   cur_col_128  7368.0  58.039319  3.103453  49.6  57.000  58.0  61.1  62.0
# 8   cur_col_137  7368.0  58.124389  3.539227  49.7  55.800  59.6  61.5  63.2
# 9   cur_col_138  7368.0  58.970494  3.784111  49.5  58.000  60.0  62.0  63.7
# 10  cur_col_139  7368.0  58.446865  3.815665  50.6  55.800  58.0  62.9  63.4
# ...

# %% [markdown]
# # class Variable Distribution

# %%
t=pd.DataFrame(df['class'].value_counts()).reset_index()
t=t.rename(columns={"index":"Class","class":"Count"})
# Pie plot
plt.axis("equal")
plt.pie(t['Count'],labels=t['Class'],
autopct='%0.2f%%',
shadow=True)
plt.title('Class Distribution')
#plt.show()
plt.savefig('piechart1.png',bbox_inches='tight')

# %% [markdown]
# # pairplot

# %%
#sns.set(style='whitegrid', context='notebook')
#sns.pairplot(df[0:40])
#plt.show()

# %% [markdown]
# # Correlation matrix

# %%
corr_matrix=pd.DataFrame(df[0:40].corr(method='pearson')).reset_index()
# Re-name Column name
corr_matrix=corr_matrix.rename(columns={0:"Variable"})
corr_matrix
# Out:
# 0      Variable  cur_col_113  cur_col_114  cur_col_115  cur_col_116  \
# 0   cur_col_113     1.000000    -0.563775    -0.170574    -0.129541
# 1   cur_col_114    -0.563775     1.000000     0.369372     0.235862
# 2   cur_col_115    -0.170574     0.369372     1.000000     0.628808
# 3   cur_col_116    -0.129541     0.235862     0.628808     1.000000
# 4   cur_col_125    -0.006698     0.126823     0.482690     0.405695
# 5   cur_col_126    -0.166394     0.261476     0.820501     0.690128
# 6   cur_col_127    -0.275933     0.339682     0.811887     0.555585
# 7   cur_col_128    -0.218887     0.251162     0.566055     0.232927
# 8   cur_col_137    -0.104219     0.372683     0.663419     0.425251
# 9   cur_col_138    -0.137473     0.116554     0.384296     0.419384
# 10  cur_col_139    -0.199780     0.305678     0.883684     0.675203
# 11  cur_col_140    -0.223158     0.344678     0.415359     0.298722
# 12  cur_col_149    -0.157106     0.200678     0.575462     0.402696
# ...

# %% [markdown]
# # Convert Calss Varibale to binary

# %%
df['outcome'] = df['class'].map({'no_urine':0,'urine':1})
df
# Out:
# 0    cur_col_113  cur_col_114  cur_col_115  cur_col_116  cur_col_125  \
# 1           50.8         51.3         51.1         51.2         50.8
# 2           50.9         51.1         51.1         51.1         51.4
# 3           50.9         51.1         51.1         51.3         51.1
# 4           50.9         51.1         51.1         51.3         51.3
# 5           51.0         50.9         51.1         51.1         51.0
# ..           ...          ...          ...          ...          ...
# 595         53.1         55.9         55.8         55.5         52.7
# 596         53.2         55.9         55.8         55.5         52.5
# 597         53.1         55.8         55.8         55.5         52.5
# 598         53.1         55.8         55.8         55.6         52.5
# 599         53.1         55.9         55.8         55.6         52.8
#
# 0    cur_col_126  cur_col_127  cur_col_128  cur_col_137  cur_col_138  ...  \
# ...

# %% [markdown]
# # 1- Logistic Regression

# %%
# Convert Data Set into Features and outcome
X = df.iloc[:, 0:40].values
y = df.iloc[:, -1].values

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Fitting Logistic Regression to the Training set
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = pd.DataFrame(confusion_matrix(y_test, y_pred))

from sklearn.metrics import accuracy_score
acc= accuracy_score(y_test, y_pred, normalize=True)

from sklearn.metrics import precision_score
pre=precision_score(y_test, y_pred)

from sklearn.metrics import recall_score
rec=precision_score(y_test, y_pred)

from sklearn.metrics import f1_score
f1sc=precision_score(y_test, y_pred)


from sklearn.metrics import classification_report
cr= classification_report(y_test, y_pred)
# Out:
# C:\Users\Irfan Kareem\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
cm
# Out:
#      0     1
# 0  115     1
# 1    2  1356

# %%
acc
# Out:
# 0.9979647218453188

# %%
pre
# Out:
# 0.9992630803242447

# %%
rec
# Out:
# 0.9992630803242447

# %%
f1sc
# Out:
# 0.9992630803242447

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       116
#            1       1.00      1.00      1.00      1358
#
#     accuracy                           1.00      1474
#    macro avg       0.99      0.99      0.99      1474
# weighted avg       1.00      1.00      1.00      1474

# %% [markdown]
# # 2- K Nearest Neighbors(K-NN)

# %%
# Convert Data Set into Features and outcome
X = df.iloc[:, 0:40].values
y = df.iloc[:, -1].values

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

#Fitting K-NN to the Training set
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = pd.DataFrame(confusion_matrix(y_test, y_pred))


from sklearn.metrics import accuracy_score
acc= accuracy_score(y_test, y_pred, normalize=True)

from sklearn.metrics import precision_score
pre=precision_score(y_test, y_pred)

from sklearn.metrics import recall_score
rec=precision_score(y_test, y_pred)

from sklearn.metrics import f1_score
f1sc=precision_score(y_test, y_pred)


from sklearn.metrics import classification_report
cr= classification_report(y_test, y_pred)

# %%
cm
# Out:
#      0     1
# 0  116     0
# 1    0  1358

# %%
acc
# Out:
# 1.0

# %%
pre
# Out:
# 1.0

# %%
rec
# Out:
# 1.0

# %%
f1sc
# Out:
# 1.0

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       116
#            1       1.00      1.00      1.00      1358
#
#     accuracy                           1.00      1474
#    macro avg       1.00      1.00      1.00      1474
# weighted avg       1.00      1.00      1.00      1474

# %% [markdown]
# # 3-Support Vector Machine (SVM)

# %%
# Convert Data Set into Features and outcome
X = df.iloc[:, 0:40].values
y = df.iloc[:, -1].values

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Fitting SVM to the Training set
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = pd.DataFrame(confusion_matrix(y_test, y_pred))


from sklearn.metrics import accuracy_score
acc= accuracy_score(y_test, y_pred, normalize=True)

from sklearn.metrics import precision_score
pre=precision_score(y_test, y_pred)

from sklearn.metrics import recall_score
rec=precision_score(y_test, y_pred)

from sklearn.metrics import f1_score
f1sc=precision_score(y_test, y_pred)


from sklearn.metrics import classification_report
cr= classification_report(y_test, y_pred)

# %%
cm
# Out:
#      0     1
# 0  116     0
# 1    1  1357

# %%
acc
# Out:
# 0.9993215739484396

# %%
pre
# Out:
# 1.0

# %%
f1sc
# Out:
# 1.0

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       116
#            1       1.00      1.00      1.00      1358
#
#     accuracy                           1.00      1474
#    macro avg       1.00      1.00      1.00      1474
# weighted avg       1.00      1.00      1.00      1474

# %% [markdown]
# # 4- SVM ( Radial Basis Function kernel (RBF) or Gaussian kernel)

# %%
# Convert Data Set into Features and outcome
X = df.iloc[:, 0:40].values
y = df.iloc[:, -1].values

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Fitting Kernel SVM to the Training set
from sklearn.svm import SVC 
classifier = SVC(kernel = 'rbf', random_state = 0)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = pd.DataFrame(confusion_matrix(y_test, y_pred))


from sklearn.metrics import accuracy_score
acc= accuracy_score(y_test, y_pred, normalize=True)

from sklearn.metrics import precision_score
pre=precision_score(y_test, y_pred)

from sklearn.metrics import recall_score
rec=precision_score(y_test, y_pred)

from sklearn.metrics import f1_score
f1sc=precision_score(y_test, y_pred)


from sklearn.metrics import classification_report
cr= classification_report(y_test, y_pred)

# %%
cm
# Out:
#      0     1
# 0  116     0
# 1    0  1358

# %%
acc
# Out:
# 1.0

# %%
pre
# Out:
# 1.0

# %%
f1sc
# Out:
# 1.0

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       116
#            1       1.00      1.00      1.00      1358
#
#     accuracy                           1.00      1474
#    macro avg       1.00      1.00      1.00      1474
# weighted avg       1.00      1.00      1.00      1474

# %% [markdown]
# # 5- SVM ( Polynomial kernel)

# %%
# Convert Data Set into Features and outcome
X = df.iloc[:, 0:40].values
y = df.iloc[:, -1].values

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Fitting Kernel SVM to the Training set
from sklearn.svm import SVC
classifier = SVC(kernel = 'poly', random_state = 0)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = pd.DataFrame(confusion_matrix(y_test, y_pred))


from sklearn.metrics import accuracy_score
acc= accuracy_score(y_test, y_pred, normalize=True)

from sklearn.metrics import precision_score
pre=precision_score(y_test, y_pred)

from sklearn.metrics import recall_score
rec=precision_score(y_test, y_pred)

from sklearn.metrics import f1_score
f1sc=precision_score(y_test, y_pred)


from sklearn.metrics import classification_report
cr= classification_report(y_test, y_pred)

# %%
acc
# Out:
# 0.9993215739484396

# %%
pre
# Out:
# 1.0

# %%
rec
# Out:
# 1.0

# %%
f1sc
# Out:
# 1.0

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       116
#            1       1.00      1.00      1.00      1358
#
#     accuracy                           1.00      1474
#    macro avg       1.00      1.00      1.00      1474
# weighted avg       1.00      1.00      1.00      1474

# %% [markdown]
# # 6- SVM (sigmoid kernel)

# %%
# Convert Data Set into Features and outcome
X = df.iloc[:, 0:40].values
y = df.iloc[:, -1].values


# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)


# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Fitting Kernel SVM to the Training set
from sklearn.svm import SVC
classifier = SVC(kernel = 'sigmoid', random_state = 0)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)


# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = pd.DataFrame(confusion_matrix(y_test, y_pred))


from sklearn.metrics import accuracy_score
acc= accuracy_score(y_test, y_pred, normalize=True)

from sklearn.metrics import precision_score
pre=precision_score(y_test, y_pred)

from sklearn.metrics import recall_score
rec=precision_score(y_test, y_pred)

from sklearn.metrics import f1_score
f1sc=precision_score(y_test, y_pred)


from sklearn.metrics import classification_report
cr= classification_report(y_test, y_pred)

# %%
acc
# Out:
# 0.8616010854816825

# %%
pre
# Out:
# 0.9364599092284418

# %%
rec
# Out:
# 0.9364599092284418

# %%
f1sc
# Out:
# 0.9364599092284418

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.21      0.28      0.24       116
#            1       0.94      0.91      0.92      1358
#
#     accuracy                           0.86      1474
#    macro avg       0.57      0.59      0.58      1474
# weighted avg       0.88      0.86      0.87      1474

# %% [markdown]
# # 7-Naïve Bayes

# %%
# Convert Data Set into Features and outcome
X = df.iloc[:, 0:40].values
y = df.iloc[:, -1].values

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)


# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Fitting Naïve Bayes to the Training set
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = pd.DataFrame(confusion_matrix(y_test, y_pred))


from sklearn.metrics import accuracy_score
acc= accuracy_score(y_test, y_pred, normalize=True)

from sklearn.metrics import precision_score
pre=precision_score(y_test, y_pred)

from sklearn.metrics import recall_score
rec=precision_score(y_test, y_pred)

from sklearn.metrics import f1_score
f1sc=precision_score(y_test, y_pred)


from sklearn.metrics import classification_report
cr= classification_report(y_test, y_pred)

# %%
cm
# Out:
#      0     1
# 0  114     2
# 1  120  1238

# %%
acc
# Out:
# 0.9172320217096337

# %%
pre
# Out:
# 0.9983870967741936

# %%
rec
# Out:
# 0.9983870967741936

# %%
f1sc
# Out:
# 0.9983870967741936

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.98      0.65       116
#            1       1.00      0.91      0.95      1358
#
#     accuracy                           0.92      1474
#    macro avg       0.74      0.95      0.80      1474
# weighted avg       0.96      0.92      0.93      1474

# %% [markdown]
# # 8-Decision Tree Classification

# %%
# Convert Data Set into Features and outcome
X = df.iloc[:, 0:40].values
y = df.iloc[:, -1].values


# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)


# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)


# Fitting Decision Tree Classification to the Training set
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)


# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = pd.DataFrame(confusion_matrix(y_test, y_pred))


from sklearn.metrics import accuracy_score
acc= accuracy_score(y_test, y_pred, normalize=True)

from sklearn.metrics import precision_score
pre=precision_score(y_test, y_pred)

from sklearn.metrics import recall_score
rec=precision_score(y_test, y_pred)

from sklearn.metrics import f1_score
f1sc=precision_score(y_test, y_pred)


from sklearn.metrics import classification_report
cr= classification_report(y_test, y_pred)

# %%
acc
# Out:
# 1.0

# %%
pre
# Out:
# 1.0

# %%
rec
# Out:
# 1.0

# %%
f1sc
# Out:
# 1.0

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       116
#            1       1.00      1.00      1.00      1358
#
#     accuracy                           1.00      1474
#    macro avg       1.00      1.00      1.00      1474
# weighted avg       1.00      1.00      1.00      1474

# %% [markdown]
# # 9-Random Forest Classification

# %%
# Convert Data Set into Features and outcome
X = df.iloc[:, 0:40].values
y = df.iloc[:, -1].values


# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)


# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Fitting Decision Tree Classification to the Training set
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)


# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = pd.DataFrame(confusion_matrix(y_test, y_pred))



from sklearn.metrics import accuracy_score
acc= accuracy_score(y_test, y_pred, normalize=True)

from sklearn.metrics import precision_score
pre=precision_score(y_test, y_pred)

from sklearn.metrics import recall_score
rec=precision_score(y_test, y_pred)

from sklearn.metrics import f1_score
f1sc=precision_score(y_test, y_pred)


from sklearn.metrics import classification_report
cr= classification_report(y_test, y_pred)

# %%
acc
# Out:
# 1.0

# %%
pre
# Out:
# 1.0

# %%
f1sc
# Out:
# 1.0

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       116
#            1       1.00      1.00      1.00      1358
#
#     accuracy                           1.00      1474
#    macro avg       1.00      1.00      1.00      1474
# weighted avg       1.00      1.00      1.00      1474
